# %%
# Import pandas as pd
import pandas as pd

# Assign the filename: file
file = 'Waller_Creek_Water_Quality_Data(AutoRecovered).csv'

# Read the file into a DataFrame: df
df = pd.read_csv(file)

#Filter for PARAM_TYPE = BACTTERIA AND SAMPLE_SITE_NO = 624

# %%
#Filter for PARAM_TYPE = BACTTERIA AND SAMPLE_SITE_NO = 624
bacteria_counts = df[ (df['PARAM_TYPE'] == 'Bacteria/Pathogens') & (df['SAMPLE_SITE_NO'] == 624)]
print(bacteria_counts)
print(len(bacteria_counts))
# Out:
#       DATA_REF_NO FILTER  LAT_DD_WGS84  LON_DD_WGS84         MEDIUM  \
# 50         330030  Total     30.285382     -97.73399  Surface Water
# 51         330031  Total     30.285382     -97.73399  Surface Water
# 52         330052  Total     30.285382     -97.73399  Surface Water
# 53         330053  Total     30.285382     -97.73399  Surface Water
# 54         330072  Total     30.285382     -97.73399  Surface Water
# ...           ...    ...           ...           ...            ...
# 1157      2888862  Total     30.285382     -97.73399  Surface Water
# 1161      2895908  Total     30.285382     -97.73399  Surface Water
# 1163      2903568  Total     30.285382     -97.73399  Surface Water
# 1168      2907543  Total     30.285382     -97.73399  Surface Water
# 1172      2930929  Total     30.285382     -97.73399  Surface Water
#
#               PARAM_TYPE                PARAMETER  \
# 50    Bacteria/Pathogens  FECAL COLIFORM BACTERIA
# ...

# %%
#filter data for certain columns
bacteria_site = df[['PARAM_TYPE', 'SAMPLE_SITE_NO', 'SAMPLE_DATE', 'PROJECT']]
bacteria_site_filter = bacteria_site[ (df['PARAM_TYPE'] == 'Bacteria/Pathogens') & (df['SAMPLE_SITE_NO'] == 624)]
print(bacteria_site_filter)
# Out:
#               PARAM_TYPE  SAMPLE_SITE_NO    SAMPLE_DATE  \
# 50    Bacteria/Pathogens             624  9/26/93 14:37
# 51    Bacteria/Pathogens             624  9/26/93 14:37
# 52    Bacteria/Pathogens             624  10/20/93 1:06
# 53    Bacteria/Pathogens             624  10/20/93 1:06
# 54    Bacteria/Pathogens             624  10/20/93 2:05
# ...                  ...             ...            ...
# 1157  Bacteria/Pathogens             624   2/1/21 11:20
# 1161  Bacteria/Pathogens             624  4/12/21 13:00
# 1163  Bacteria/Pathogens             624  7/13/21 12:45
# 1168  Bacteria/Pathogens             624  9/14/21 12:35
# 1172  Bacteria/Pathogens             624  1/27/22 14:20
#
#                                   PROJECT
# 50                Waller Creek Stormwater
# 51                Waller Creek Stormwater
# 52                Waller Creek Stormwater
# 53                Waller Creek Stormwater
# 54                Waller Creek Stormwater
# ...

# %%
#Filter for PARAM_TYPE = Alkalinity/Hardness/pH AND SAMPLE_SITE_NO = 624
ph_counts = df[ (df['PARAM_TYPE'] == 'Alkalinity/Hardness/pH') & (df['SAMPLE_SITE_NO'] == 624)]
print(ph_counts)
print(len(ph_counts))
# Out:
#       DATA_REF_NO FILTER  LAT_DD_WGS84  LON_DD_WGS84         MEDIUM  \
# 1293       471737  Total     30.285382     -97.73399  Surface Water
# 1297       472003  Total     30.285382     -97.73399  Surface Water
# 1301       476985  Total     30.285382     -97.73399  Surface Water
# 1303       480205  Total     30.285382     -97.73399  Surface Water
# 1308       481502  Total     30.285382     -97.73399  Surface Water
# ...           ...    ...           ...           ...            ...
# 1810      2900970  Total     30.285382     -97.73399  Surface Water
# 1812      2897282  Total     30.285382     -97.73399  Surface Water
# 1818      2902863  Total     30.285382     -97.73399  Surface Water
# 1823      2922906  Total     30.285382     -97.73399  Surface Water
# 1826      2935788  Total     30.285382     -97.73399  Surface Water
#
#                   PARAM_TYPE PARAMETER                              PROJECT  \
# ...

# %%
#filter data for certain columns
ph_site = df[['PARAM_TYPE', 'SAMPLE_SITE_NO', 'SAMPLE_DATE', 'PROJECT']]
ph_site_filter = ph_site[ (df['PARAM_TYPE'] == 'Alkalinity/Hardness/pH') & (df['SAMPLE_SITE_NO'] == 624)]
print(ph_site_filter)
# Out:
#                   PARAM_TYPE  SAMPLE_SITE_NO    SAMPLE_DATE  \
# 1293  Alkalinity/Hardness/pH             624   4/6/99 13:30
# 1297  Alkalinity/Hardness/pH             624  6/29/99 13:00
# 1301  Alkalinity/Hardness/pH             624  11/4/99 15:30
# 1303  Alkalinity/Hardness/pH             624   2/4/00 10:20
# 1308  Alkalinity/Hardness/pH             624  2/16/00 10:30
# ...                      ...             ...            ...
# 1810  Alkalinity/Hardness/pH             624  6/25/21 14:00
# 1812  Alkalinity/Hardness/pH             624  7/13/21 12:45
# 1818  Alkalinity/Hardness/pH             624  9/14/21 12:35
# 1823  Alkalinity/Hardness/pH             624  1/27/22 14:20
# 1826  Alkalinity/Hardness/pH             624  3/29/22 14:20
#
#                                   PROJECT
# 1293                   Waller Creek Study
# 1297                   Waller Creek Study
# 1301                   Waller Creek Study
# 1303                      Water Watch Dog
# ...

# %%
#Filter for PARAM_TYPE = Oxygen AND SAMPLE_SITE_NO = 624
o2_counts = df[ (df['PARAM_TYPE'] == 'Oxygen') & (df['SAMPLE_SITE_NO'] == 624)]
print(o2_counts)
print(len(o2_counts))
# Out:
#       DATA_REF_NO     FILTER  LAT_DD_WGS84  LON_DD_WGS84         MEDIUM  \
# 1925       330044      Total     30.285382     -97.73399  Surface Water
# 1926       330033      Total     30.285382     -97.73399  Surface Water
# 1935       330064      Total     30.285382     -97.73399  Surface Water
# 1936       330055      Total     30.285382     -97.73399  Surface Water
# 1937       330084      Total     30.285382     -97.73399  Surface Water
# ...           ...        ...           ...           ...            ...
# 3227      2889998  Dissolved     30.285382     -97.73399  Surface Water
# 3230      2897329  Dissolved     30.285382     -97.73399  Surface Water
# 3236      2903130  Dissolved     30.285382     -97.73399  Surface Water
# 3241      2922896  Dissolved     30.285382     -97.73399  Surface Water
# 3244      2935762  Dissolved     30.285382     -97.73399  Surface Water
#
#      PARAM_TYPE                                   PARAMETER  \
# ...

# %%
#filter data for certain columns
o2_site = df[['PARAM_TYPE', 'SAMPLE_SITE_NO', 'SAMPLE_DATE', 'PROJECT']]
o2_site_filter = o2_site[ (df['PARAM_TYPE'] == 'Oxygen') & (df['SAMPLE_SITE_NO'] == 624)]
print(o2_site_filter)
# Out:
#      PARAM_TYPE  SAMPLE_SITE_NO    SAMPLE_DATE  \
# 1925     Oxygen             624  9/26/93 14:37
# 1926     Oxygen             624  9/26/93 14:37
# 1935     Oxygen             624  10/20/93 1:06
# 1936     Oxygen             624  10/20/93 1:06
# 1937     Oxygen             624  10/20/93 2:05
# ...         ...             ...            ...
# 3227     Oxygen             624  4/12/21 13:00
# 3230     Oxygen             624  7/13/21 12:45
# 3236     Oxygen             624  9/14/21 12:35
# 3241     Oxygen             624  1/27/22 14:20
# 3244     Oxygen             624  3/29/22 14:20
#
#                                   PROJECT
# 1925              Waller Creek Stormwater
# 1926              Waller Creek Stormwater
# 1935              Waller Creek Stormwater
# 1936              Waller Creek Stormwater
# 1937              Waller Creek Stormwater
# ...                                   ...
# 3227  Environmental Integrity Index (EII)
# 3230  Environmental Integrity Index (EII)
# ...
